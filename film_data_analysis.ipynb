# %% [markdown]
# # **Phase 2 : Analyse de données**

# %%
from moviespac import MovieClient, MovieConfig

# %%
# Configuration avec l’URL de votre API (Render ou locale)
config = MovieConfig(movie_base_url="https://film-api-3i06.onrender.com")
client = MovieClient(config=config)
# Out:
# MOVIE_API_BASE_URL in MovieConfig init: https://film-api-3i06.onrender.com

# %%
client.health_check()
# Out:
# {'message': 'API MovieLens opérationnelle'}

# %%
# Obtenir un film
movie = client.get_movie(1)
print(movie.title)
# Out:
# Toy Story (1995)

# %%
# Obtenir la liste des notes
ratings_df = client.list_ratings(limit= 100, output_format= 'pandas')
ratings_df.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     100 non-null    int64
#  1   movieId    100 non-null    int64
#  2   rating     100 non-null    float64
#  3   timestamp  100 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 3.3 KB

# %%
# Recuperer les stats globales
analytics = client.get_analytics()
print(analytics)
# Out:
# movie_count=9742 rating_count=100836 tag_count=3683 link_count=9742

# %%
total_ratings = analytics.movie_count
total_ratings
# Out:
# 9742

# %%
complete_ratings = client.list_ratings(limit= total_ratings, output_format= "pandas")
complete_ratings.tail(10)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 complete_ratings = client.list_ratings(limit= total_ratings, output_format= "pandas")
#       2 complete_ratings.tail(10)
#
# File c:\Users\ulric\Documents\Projects\Personnal\Movie_analytics\.venv\Lib\site-packages\moviespac\film_client.py:89, in MovieClient.list_ratings(self, skip, limit, movie_id, user_id, min_rating, output_format)
#      87     params["min_rating"] = min_rating
#      88 response = httpx.get(url, params=params)
# ---> 89 response.raise_for_status()
#      90 return self._format_output(response.json(), RatingSimple, output_format)
#
# File c:\Users\ulric\Documents\Projects\Personnal\Movie_analytics\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '422 Unprocessable Entity' for url 'https://film-api-3i06.onrender.com/ratings?skip=0&limit=9742'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/422

# %% [markdown]
# L'erreur ci-dessus survient a cause de la limite des donnees par requete. Pour contourner cela, on peut realiser un batch processing (traitement par lot).

# %%
import time
import pandas as pd

# %%
# 1. Récupérer le total d’évaluations
total_ratings = client.get_analytics().rating_count
batch_size = 1000
all_ratings = []

# 2. Boucle sur les batches avec pause
for skip in range(0, total_ratings, batch_size):
    print(f"Téléchargement des lignes {skip} à {skip + batch_size}...")
    batch_df = client.list_ratings(skip=skip, limit=batch_size, output_format="pandas")
    all_ratings.append(batch_df)
    time.sleep(0.5)  # pause de 0.5 seconde

# 3. Concaténer tous les résultats
complete_ratings_df = pd.concat(all_ratings, ignore_index=True)

complete_ratings_df
# Out:
# Téléchargement des lignes 0 à 1000...
# Téléchargement des lignes 1000 à 2000...
# Téléchargement des lignes 2000 à 3000...
# Téléchargement des lignes 3000 à 4000...
# Téléchargement des lignes 4000 à 5000...
# Téléchargement des lignes 5000 à 6000...
# Téléchargement des lignes 6000 à 7000...
# Téléchargement des lignes 7000 à 8000...
# Téléchargement des lignes 8000 à 9000...
# Téléchargement des lignes 9000 à 10000...
# Téléchargement des lignes 10000 à 11000...
# Téléchargement des lignes 11000 à 12000...
# Téléchargement des lignes 12000 à 13000...
# Téléchargement des lignes 13000 à 14000...
# Téléchargement des lignes 14000 à 15000...
# Téléchargement des lignes 15000 à 16000...
# Téléchargement des lignes 16000 à 17000...
# Téléchargement des lignes 17000 à 18000...
# Téléchargement des lignes 18000 à 19000...
# Téléchargement des lignes 19000 à 20000...
# Téléchargement des lignes 20000 à 21000...
# Téléchargement des lignes 21000 à 22000...
# Téléchargement des lignes 22000 à 23000...
# Téléchargement des lignes 23000 à 24000...
# Téléchargement des lignes 24000 à 25000...
# Téléchargement des lignes 25000 à 26000...
# Téléchargement des lignes 26000 à 27000...
# Téléchargement des lignes 27000 à 28000...
# Téléchargement des lignes 28000 à 29000...
# Téléchargement des lignes 29000 à 30000...
# Téléchargement des lignes 30000 à 31000...
# Téléchargement des lignes 31000 à 32000...
# Téléchargement des lignes 32000 à 33000...
# Téléchargement des lignes 33000 à 34000...
# Téléchargement des lignes 34000 à 35000...
# Téléchargement des lignes 35000 à 36000...
# Téléchargement des lignes 36000 à 37000...
# Téléchargement des lignes 37000 à 38000...
# Téléchargement des lignes 38000 à 39000...
# Téléchargement des lignes 39000 à 40000...
# Téléchargement des lignes 40000 à 41000...
# Téléchargement des lignes 41000 à 42000...
# Téléchargement des lignes 42000 à 43000...
# Téléchargement des lignes 43000 à 44000...
# Téléchargement des lignes 44000 à 45000...
# Téléchargement des lignes 45000 à 46000...
# Téléchargement des lignes 46000 à 47000...
# Téléchargement des lignes 47000 à 48000...
# Téléchargement des lignes 48000 à 49000...
# Téléchargement des lignes 49000 à 50000...
# Téléchargement des lignes 50000 à 51000...
# Téléchargement des lignes 51000 à 52000...
# Téléchargement des lignes 52000 à 53000...
# Téléchargement des lignes 53000 à 54000...
# Téléchargement des lignes 54000 à 55000...
# Téléchargement des lignes 55000 à 56000...
# Téléchargement des lignes 56000 à 57000...
# Téléchargement des lignes 57000 à 58000...
# Téléchargement des lignes 58000 à 59000...
# Téléchargement des lignes 59000 à 60000...
# Téléchargement des lignes 60000 à 61000...
# Téléchargement des lignes 61000 à 62000...
# Téléchargement des lignes 62000 à 63000...
# Téléchargement des lignes 63000 à 64000...
# Téléchargement des lignes 64000 à 65000...
# Téléchargement des lignes 65000 à 66000...
# Téléchargement des lignes 66000 à 67000...
# Téléchargement des lignes 67000 à 68000...
# Téléchargement des lignes 68000 à 69000...
# Téléchargement des lignes 69000 à 70000...
# Téléchargement des lignes 70000 à 71000...
# Téléchargement des lignes 71000 à 72000...
# Téléchargement des lignes 72000 à 73000...
# Téléchargement des lignes 73000 à 74000...
# Téléchargement des lignes 74000 à 75000...
# Téléchargement des lignes 75000 à 76000...
# Téléchargement des lignes 76000 à 77000...
# Téléchargement des lignes 77000 à 78000...
# Téléchargement des lignes 78000 à 79000...
# Téléchargement des lignes 79000 à 80000...
# Téléchargement des lignes 80000 à 81000...
# Téléchargement des lignes 81000 à 82000...
# Téléchargement des lignes 82000 à 83000...
# Téléchargement des lignes 83000 à 84000...
# Téléchargement des lignes 84000 à 85000...
# Téléchargement des lignes 85000 à 86000...
# Téléchargement des lignes 86000 à 87000...
# Téléchargement des lignes 87000 à 88000...
# Téléchargement des lignes 88000 à 89000...
# Téléchargement des lignes 89000 à 90000...
# Téléchargement des lignes 90000 à 91000...
# Téléchargement des lignes 91000 à 92000...
# Téléchargement des lignes 92000 à 93000...
# Téléchargement des lignes 93000 à 94000...
# Téléchargement des lignes 94000 à 95000...
# Téléchargement des lignes 95000 à 96000...
# Téléchargement des lignes 96000 à 97000...
# Téléchargement des lignes 97000 à 98000...
# Téléchargement des lignes 98000 à 99000...
# Téléchargement des lignes 99000 à 100000...
# Téléchargement des lignes 100000 à 101000...
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
complete_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
# 4. Agrégation : nombre d’évaluations par utilisateur
ratings_per_user = complete_ratings_df['userId'].value_counts().rename_axis('userId').reset_index(name='rating_count')
ratings_per_user
# Out:
#      userId  rating_count
# 0       414          2698
# 1       599          2478
# 2       474          2108
# 3       448          1864
# 4       274          1346
# ..      ...           ...
# 605     442            20
# 606     278            20
# 607     147            20
# 608     320            20
# 609      53            20
#
# [610 rows x 2 columns]

# %% [markdown]
# La facon de recuperer le nombre d'évalutions par utilisateur avec le code ci-dessus est beaucoup plus couteuse en terme d'espace memoire et de temps. Pour y remedier, on peut par exemple récuperer le nombre d'évaluations par lots.

# %%
# Agréger rating_count par userId, chunk par chunk

# 1. Récupérer le total d’évaluations
total_ratings = client.get_analytics().rating_count
batch_size = 1000

# 2. Dictionnaire pour accumuler les totaux par userId
from collections import defaultdict
user_rating_counts = defaultdict(int)

# 3. Parcours des chunks
for skip in range(0, total_ratings, batch_size):
    print(f"Traitement du batch {skip} à {skip + batch_size}...")
    batch_df = client.list_ratings(skip=skip, limit=batch_size, output_format="pandas")
    
    # Comptage des évaluations par utilisateur dans le batch
    batch_counts = batch_df['userId'].value_counts()
    
    # Mise à jour du compteur global
    for user_id, count in batch_counts.items():
        user_rating_counts[user_id] += count
    
    time.sleep(0.5)

# 4. Conversion en DataFrame finale
ratings_per_user = pd.DataFrame(list(user_rating_counts.items()), columns=["userId", "rating_count"])

ratings_per_user
# Out:
# Traitement du batch 0 à 1000...
# Traitement du batch 1000 à 2000...
# Traitement du batch 2000 à 3000...
# Traitement du batch 3000 à 4000...
# Traitement du batch 4000 à 5000...
# Traitement du batch 5000 à 6000...
# Traitement du batch 6000 à 7000...
# Traitement du batch 7000 à 8000...
# Traitement du batch 8000 à 9000...
# Traitement du batch 9000 à 10000...
# Traitement du batch 10000 à 11000...
# Traitement du batch 11000 à 12000...
# Traitement du batch 12000 à 13000...
# Traitement du batch 13000 à 14000...
# Traitement du batch 14000 à 15000...
# Traitement du batch 15000 à 16000...
# Traitement du batch 16000 à 17000...
# Traitement du batch 17000 à 18000...
# Traitement du batch 18000 à 19000...
# Traitement du batch 19000 à 20000...
# Traitement du batch 20000 à 21000...
# Traitement du batch 21000 à 22000...
# Traitement du batch 22000 à 23000...
# Traitement du batch 23000 à 24000...
# Traitement du batch 24000 à 25000...
# Traitement du batch 25000 à 26000...
# Traitement du batch 26000 à 27000...
# Traitement du batch 27000 à 28000...
# Traitement du batch 28000 à 29000...
# Traitement du batch 29000 à 30000...
# Traitement du batch 30000 à 31000...
# Traitement du batch 31000 à 32000...
# Traitement du batch 32000 à 33000...
# Traitement du batch 33000 à 34000...
# Traitement du batch 34000 à 35000...
# Traitement du batch 35000 à 36000...
# Traitement du batch 36000 à 37000...
# Traitement du batch 37000 à 38000...
# Traitement du batch 38000 à 39000...
# Traitement du batch 39000 à 40000...
# Traitement du batch 40000 à 41000...
# Traitement du batch 41000 à 42000...
# Traitement du batch 42000 à 43000...
# Traitement du batch 43000 à 44000...
# Traitement du batch 44000 à 45000...
# Traitement du batch 45000 à 46000...
# Traitement du batch 46000 à 47000...
# Traitement du batch 47000 à 48000...
# Traitement du batch 48000 à 49000...
# Traitement du batch 49000 à 50000...
# Traitement du batch 50000 à 51000...
# Traitement du batch 51000 à 52000...
# Traitement du batch 52000 à 53000...
# Traitement du batch 53000 à 54000...
# Traitement du batch 54000 à 55000...
# Traitement du batch 55000 à 56000...
# Traitement du batch 56000 à 57000...
# Traitement du batch 57000 à 58000...
# Traitement du batch 58000 à 59000...
# Traitement du batch 59000 à 60000...
# Traitement du batch 60000 à 61000...
# Traitement du batch 61000 à 62000...
# Traitement du batch 62000 à 63000...
# Traitement du batch 63000 à 64000...
# Traitement du batch 64000 à 65000...
# Traitement du batch 65000 à 66000...
# Traitement du batch 66000 à 67000...
# Traitement du batch 67000 à 68000...
# Traitement du batch 68000 à 69000...
# Traitement du batch 69000 à 70000...
# Traitement du batch 70000 à 71000...
# Traitement du batch 71000 à 72000...
# Traitement du batch 72000 à 73000...
# Traitement du batch 73000 à 74000...
# Traitement du batch 74000 à 75000...
# Traitement du batch 75000 à 76000...
# Traitement du batch 76000 à 77000...
# Traitement du batch 77000 à 78000...
# Traitement du batch 78000 à 79000...
# Traitement du batch 79000 à 80000...
# Traitement du batch 80000 à 81000...
# Traitement du batch 81000 à 82000...
# Traitement du batch 82000 à 83000...
# Traitement du batch 83000 à 84000...
# Traitement du batch 84000 à 85000...
# Traitement du batch 85000 à 86000...
# Traitement du batch 86000 à 87000...
# Traitement du batch 87000 à 88000...
# Traitement du batch 88000 à 89000...
# Traitement du batch 89000 à 90000...
# Traitement du batch 90000 à 91000...
# Traitement du batch 91000 à 92000...
# Traitement du batch 92000 à 93000...
# Traitement du batch 93000 à 94000...
# Traitement du batch 94000 à 95000...
# Traitement du batch 95000 à 96000...
# Traitement du batch 96000 à 97000...
# Traitement du batch 97000 à 98000...
# Traitement du batch 98000 à 99000...
# Traitement du batch 99000 à 100000...
# Traitement du batch 100000 à 101000...
#      userId  rating_count
# 0         6           314
# 1         1           232
# 2         4           216
# 3         7           152
# 4         5            44
# ..      ...           ...
# 605     604           100
# 606     608           831
# 607     607           187
# 608     610          1302
# 609     609            37
#
# [610 rows x 2 columns]

# %%
ratings_per_user =ratings_per_user.sort_values(by="rating_count", ascending= False)
ratings_per_user
# Out:
#      userId  rating_count
# 410     414          2698
# 597     599          2478
# 471     474          2108
# 438     448          1864
# 268     274          1346
# ..      ...           ...
# 447     442            20
# 199     194            20
# 206     207            20
# 321     320            20
# 583     576            20
#
# [610 rows x 2 columns]

# %% [markdown]
# ## Question Business pertinente

# %% [markdown]
# **Quels sont les films les mieux notés ?**

# %%
top_ratings = client.get_top_rated_movies(limit= 100, output_format= "pandas")
top_ratings.head(10)
# Out:
#    movieId                                              title  \
# 0      318                   Shawshank Redemption, The (1994)
# 1      858                              Godfather, The (1972)
# 2     2959                                  Fight Club (1999)
# 3     1276                              Cool Hand Luke (1967)
# 4      750  Dr. Strangelove or: How I Learned to Stop Worr...
# 5      904                                 Rear Window (1954)
# 6     1221                     Godfather: Part II, The (1974)
# 7    48516                               Departed, The (2006)
# 8     1213                                  Goodfellas (1990)
# 9      912                                  Casablanca (1942)
#
#                         genres  average_rating  rating_count
# 0                  Crime|Drama        4.429022           317
# 1                  Crime|Drama        4.289062           192
# 2  Action|Crime|Drama|Thriller        4.272936           218
# 3                        Drama        4.271930            57
# 4                   Comedy|War        4.268041            97
# 5             Mystery|Thriller        4.261905            84
# 6                  Crime|Drama        4.259690           129
# 7         Crime|Drama|Thriller        4.252336           107
# 8                  Crime|Drama        4.250000           126
# 9                Drama|Romance        4.240000           100

# %% [markdown]
# `top_ratings` renvoi les films qui sont les mieux notes en moyenne et qui ont obtenus plus de 50 votes.

# %% [markdown]
# **Quels sont les genres les plus populaires ?**

# %%
popular_genres = client.get_popular_genres(limit= 100, output_format= "pandas")
popular_genres.tail(20)
# Out:
#           genre  count
# 0         Drama   4361
# 1        Comedy   3756
# 2      Thriller   1894
# 3        Action   1828
# 4       Romance   1596
# 5     Adventure   1263
# 6         Crime   1199
# 7        Sci-Fi    980
# 8        Horror    978
# 9       Fantasy    779
# 10     Children    664
# 11    Animation    611
# 12      Mystery    573
# 13  Documentary    440
# 14          War    382
# 15      Musical    334
# 16      Western    167
# 17         IMAX    158
# 18    Film-Noir     87

# %% [markdown]
# **Quels genres de films les utilisateurs taguent le plus positivement (note ≥ 4.0), et quels sont les tags les plus fréquents associés à ces genres ?**
#
# ### Pourquoi c’est pertinent ?
# - Cela permet de **comprendre les préférences des utilisateurs** non seulement à travers les notes, mais aussi via les **tags qualitatifs** qu’ils ajoutent.
# - Un **analyste marketing** ou un **algorithme de recommandation** peut utiliser cette information pour :
#   - recommander des films similaires,
#   - optimiser la classification des films,
#   - mieux comprendre les "moods" ou intentions derrière les notes élevées.
#
# ---
#
# ### Données nécessaires (via SDK + API) :
# - **`ratings`** : pour filtrer sur les évaluations élevées (`rating ≥ 4.0`).
# - **`tags`** : pour voir quels tags sont utilisés sur les mêmes `(userId, movieId)`.
# - **`movies`** : pour enrichir avec les genres correspondants.
#
# ---
#
# ### Étapes principales :
# 1. Lister toutes les **ratings ≥ 4.0** (en batch si nécessaire).
# 2. Pour chaque `(user_id, movieId)` filtré, essayer de récupérer un **tag** via `client.get_tag(...)` ou en listant tous les tags et croisant.
# 3. Récupérer les **genres du film** via `client.get_movie(movieId)`.
# 4. Agréger : **genre ↔️ tag ↔️ fréquence**.

# %%
# Étape 1 : Récupérer les évaluations élevées (rating >= 4.0) par lots

chunk_size = 1000
skip = 0
all_high_ratings = []

while True:
    chunk = client.list_ratings(
        skip=skip,
        limit=chunk_size,
        min_rating=4.0,
        output_format="pandas"
    )
    
    if chunk.empty:
        break
    
    all_high_ratings.append(chunk)
    skip += chunk_size
    time.sleep(0.5)  # Pause entre appels pour éviter les erreurs 429

# Fusionner tous les chunks
high_ratings_df = pd.concat(all_high_ratings, ignore_index=True)
print(high_ratings_df.shape)
high_ratings_df
# Out:
# (48580, 4)
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 1           1        3     4.0   964981247
# 2           1        6     4.0   964982224
# 3           1       47     5.0   964983815
# 4           1       50     5.0   964982931
# ...       ...      ...     ...         ...
# 48575     610   166528     4.0  1493879365
# 48576     610   166534     4.0  1493848402
# 48577     610   168248     5.0  1493850091
# 48578     610   168250     5.0  1494273047
# 48579     610   168252     5.0  1493846352
#
# [48580 rows x 4 columns]

# %%
# Étape 2 : Identifier les couples (userId, movieId) uniques

user_movie_pairs = high_ratings_df[['userId', 'movieId']].drop_duplicates()
user_movie_pairs
# Out:
#        userId  movieId
# 0           1        1
# 1           1        3
# 2           1        6
# 3           1       47
# 4           1       50
# ...       ...      ...
# 48575     610   166528
# 48576     610   166534
# 48577     610   168248
# 48578     610   168250
# 48579     610   168252
#
# [48580 rows x 2 columns]

# %%
#  Étape 3 : Récupérer les tags correspondants

# Récupération de tous les tags
all_tags = []
skip = 0
chunk_size = 1000
while True:
    tag_chunk = client.list_tags(skip=skip, limit=chunk_size, output_format="pandas")
    if tag_chunk.empty:
        break
    all_tags.append(tag_chunk)
    skip += chunk_size
    time.sleep(0.5)

all_tags_df = pd.concat(all_tags, ignore_index=True)

all_tags_df
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
all_tags
# Out:
# [     userId  movieId               tag   timestamp
#  0         2    60756             funny  1445714994
#  1         2    60756   Highly quotable  1445714996
#  2         2    60756      will ferrell  1445714992
#  3         2    89774      Boxing story  1445715207
#  4         2    89774               MMA  1445715200
#  ..      ...      ...               ...         ...
#  995     474       26       Shakespeare  1138137603
#  996     474       28  In Netflix queue  1137201942
#  997     474       28       Jane Austen  1137180037
#  998     474       29        kidnapping  1138137473
#  999     474       31       high school  1137375502
#
#  [1000 rows x 4 columns],
#       userId  movieId            tag   timestamp
#  0       474       31        teacher  1137375502
#  1       474       32    time travel  1137206826
#  2       474       34   Animal movie  1137180956
#  3       474       34           pigs  1137205237
#  4       474       36  death penalty  1137202363
#  ..      ...      ...            ...         ...
#  995     474     5398         boxing  1138039410
#  996     474     5404          books  1138039075
#  997     474     5445         future  1137206007
#  998     474     5446      Australia  1137181573
#  999     474     5450     sisterhood  1138039255
#
#  [1000 rows x 4 columns],
#       userId  movieId               tag   timestamp
#  0       474     5450             women  1138039255
#  1       474     5451        disability  1137375287
#  2       474     5451    mental illness  1137375287
#  3       474     5470       Oscar Wilde  1137181530
#  4       474     5475  In Netflix queue  1137201978
#  ..      ...      ...               ...         ...
#  995     567     4144       melancholic  1525283526
#  996     567     4144        melancholy  1525283531
#  997     567     4144             moody  1525283533
#  998     567     4144         nocturnal  1525283537
#  999     567     4144          romantic  1525283568
#
#  [1000 rows x 4 columns],
#       userId  movieId                 tag   timestamp
#  0       567     4144              Unique  1525283560
#  1       567     4144  visually appealing  1525283544
#  2       567     4144   visually stunning  1525283550
#  3       567     4226            cerebral  1525282541
#  4       567     4226           dreamlike  1525282545
#  ..      ...      ...                 ...         ...
#  678     606     7382           for katie  1171234019
#  679     606     7936             austere  1173392334
#  680     610     3265              gun fu  1493843984
#  681     610     3265    heroic bloodshed  1493843978
#  682     610   168248    Heroic Bloodshed  1493844270
#
#  [683 rows x 4 columns]]

# %%
# Merge avec les high ratings
tagged_high_ratings = pd.merge(user_movie_pairs, all_tags_df, on=["userId", "movieId"])
print(tagged_high_ratings.shape)
tagged_high_ratings
# Out:
# (2378, 4)
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 2373     606     6107      World War II  1178473747
# 2374     606     7382         for katie  1171234019
# 2375     610     3265            gun fu  1493843984
# 2376     610     3265  heroic bloodshed  1493843978
# 2377     610   168248  Heroic Bloodshed  1493844270
#
# [2378 rows x 4 columns]

# %%
# Étape 4 : Récupérer les genres associés aux movieId

def get_movie_genre(movie_id):
    try:
        movie = client.get_movie(movie_id)
        return movie.genres
    except:
        return ""

# Appliquer uniquement aux movieId uniques qu’on a en tags
unique_movie_ids = tagged_high_ratings['movieId'].unique()

movie_genres = {
    movie_id: get_movie_genre(movie_id)
    for movie_id in unique_movie_ids
}

# Ajoutons la colonne genre
tagged_high_ratings['genres'] = tagged_high_ratings['movieId'].map(movie_genres)
print(tagged_high_ratings.shape)
tagged_high_ratings
# Out:
# (2378, 5)
#       userId  movieId               tag   timestamp  \
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 2373     606     6107      World War II  1178473747
# 2374     606     7382         for katie  1171234019
# 2375     610     3265            gun fu  1493843984
# 2376     610     3265  heroic bloodshed  1493843978
# 2377     610   168248  Heroic Bloodshed  1493844270
#
#                            genres
# 0                          Comedy
# 1                          Comedy
# 2                          Comedy
# 3                           Drama
# 4                           Drama
# ...                           ...
# 2373                    Drama|War
# 2374       Drama|Mystery|Thriller
# 2375  Action|Crime|Drama|Thriller
# 2376  Action|Crime|Drama|Thriller
# 2377        Action|Crime|Thriller
#
# [2378 rows x 5 columns]

# %%
movie_genres
# Out:
# {np.int64(60756): 'Comedy',
#  np.int64(89774): 'Drama',
#  np.int64(106782): 'Comedy|Crime|Drama',
#  np.int64(431): 'Crime|Drama',
#  np.int64(1221): 'Crime|Drama',
#  np.int64(5995): 'Drama|War',
#  np.int64(44665): 'Crime|Drama|Mystery',
#  np.int64(52604): 'Crime|Drama|Mystery|Thriller',
#  np.int64(144210): 'Documentary',
#  np.int64(109487): 'Sci-Fi|IMAX',
#  np.int64(2): 'Adventure|Children|Fantasy',
#  np.int64(110): 'Action|Drama|War',
#  np.int64(410): 'Children|Comedy|Fantasy',
#  np.int64(2023): 'Crime|Drama|Mystery|Thriller',
#  np.int64(2124): 'Children|Comedy|Fantasy',
#  np.int64(3578): 'Action|Adventure|Drama',
#  np.int64(4223): 'Drama|War',
#  np.int64(5388): 'Action|Crime|Drama|Mystery|Thriller',
#  np.int64(7153): 'Action|Adventure|Drama|Fantasy',
#  np.int64(8641): 'Comedy',
#  np.int64(27660): 'Action|Animation|Drama|Sci-Fi',
#  np.int64(27706): 'Adventure|Children|Comedy|Fantasy',
#  np.int64(27808): 'Comedy|Drama|Romance',
#  np.int64(27831): 'Crime|Drama|Thriller',
#  np.int64(33162): 'Action|Drama|Romance|War',
#  np.int64(37729): 'Animation|Comedy|Fantasy|Musical|Romance',
#  np.int64(38061): 'Comedy|Crime|Mystery|Thriller',
#  np.int64(46972): 'Action|Comedy|Fantasy|IMAX',
#  np.int64(46976): 'Comedy|Drama|Fantasy|Romance',
#  np.int64(49130): 'Comedy|Drama|Romance',
#  np.int64(49530): 'Action|Adventure|Crime|Drama|Thriller|War',
#  np.int64(59501): 'Adventure|Children|Fantasy',
#  np.int64(61024): 'Action|Comedy|Crime',
#  np.int64(68848): 'Adventure|Comedy|Crime|Romance',
#  np.int64(99114): 'Action|Drama|Western',
#  np.int64(104863): 'Comedy|Drama|Romance',
#  np.int64(107348): 'Comedy',
#  np.int64(115149): 'Action|Thriller',
#  np.int64(116897): 'Comedy|Drama|Thriller',
#  np.int64(122912): 'Action|Adventure|Sci-Fi',
#  np.int64(128360): 'Western',
#  np.int64(135536): 'Action|Crime|Sci-Fi',
#  np.int64(136864): 'Action|Adventure|Fantasy|Sci-Fi',
#  np.int64(139385): 'Adventure|Drama',
#  np.int64(158966): 'Drama',
#  np.int64(168248): 'Action|Crime|Thriller',
#  np.int64(174053): 'Drama|Horror|Mystery|Sci-Fi|Thriller',
#  np.int64(183611): 'Action|Comedy|Crime|Horror',
#  np.int64(187593): 'Action|Comedy|Sci-Fi',
#  np.int64(187595): 'Action|Adventure|Children|Sci-Fi',
#  np.int64(260): 'Action|Adventure|Sci-Fi',
#  np.int64(296): 'Comedy|Crime|Drama|Thriller',
#  np.int64(4896): 'Adventure|Children|Fantasy',
#  np.int64(106489): 'Adventure|Fantasy|IMAX',
#  np.int64(101142): 'Adventure|Animation|Comedy',
#  np.int64(115617): 'Action|Animation|Comedy',
#  np.int64(120635): 'Action|Crime|Thriller',
#  np.int64(1726): 'Action|Adventure|Drama|Sci-Fi',
#  np.int64(2387): 'Comedy|Crime',
#  np.int64(3052): 'Adventure|Comedy|Fantasy',
#  np.int64(5088): 'Comedy|Crime|Drama',
#  np.int64(7022): 'Action|Drama|Horror|Thriller',
#  np.int64(7254): 'Drama|Sci-Fi|Thriller',
#  np.int64(8957): 'Horror|Mystery|Thriller',
#  np.int64(9010): 'Drama|Romance',
#  np.int64(42632): 'Crime|Drama|Mystery|Thriller',
#  np.int64(58301): 'Drama|Thriller',
#  np.int64(60950): 'Comedy|Drama|Romance',
#  np.int64(62434): 'Comedy|Drama|Romance',
#  np.int64(67695): 'Action|Comedy',
#  np.int64(100083): 'Comedy',
#  np.int64(156371): 'Comedy',
#  np.int64(158872): 'Animation|Comedy',
#  np.int64(3556): 'Drama|Romance',
#  np.int64(59103): 'Action|Adventure|Comedy|Fantasy',
#  np.int64(52287): 'Action|Adventure|Animation|Children|Comedy|Sci-Fi',
#  np.int64(293): 'Action|Crime|Drama|Thriller',
#  np.int64(54286): 'Action|Crime|Thriller',
#  np.int64(104): 'Comedy',
#  np.int64(2579): 'Crime|Mystery|Thriller',
#  np.int64(4226): 'Mystery|Thriller',
#  np.int64(6283): 'Action|Animation|Sci-Fi|Thriller',
#  np.int64(27156): 'Action|Animation|Drama|Fantasy|Sci-Fi',
#  np.int64(4878): 'Drama|Mystery|Sci-Fi|Thriller',
#  np.int64(97938): 'Adventure|Drama|IMAX',
#  np.int64(6938): 'Documentary',
#  np.int64(48780): 'Drama|Mystery|Sci-Fi|Thriller',
#  np.int64(126548): 'Comedy',
#  np.int64(50872): 'Animation|Children|Drama',
#  np.int64(118696): 'Adventure|Fantasy',
#  np.int64(6711): 'Comedy|Drama|Romance',
#  np.int64(4034): 'Crime|Drama|Thriller',
#  np.int64(4995): 'Drama|Romance',
#  np.int64(6502): 'Action|Horror|Sci-Fi',
#  np.int64(55721): 'Action|Crime|Drama|Thriller',
#  np.int64(83134): 'Comedy|Horror',
#  np.int64(778): 'Comedy|Crime|Drama',
#  np.int64(4612): 'Drama',
#  np.int64(4708): 'Drama|Musical',
#  np.int64(64034): 'Drama|War',
#  np.int64(68954): 'Adventure|Animation|Children|Drama',
#  np.int64(82459): 'Western',
#  np.int64(90769): 'Documentary',
#  np.int64(96084): 'Drama',
#  np.int64(364): 'Adventure|Animation|Children|Drama|Musical|IMAX',
#  np.int64(1288): 'Comedy',
#  np.int64(1923): 'Comedy|Romance',
#  np.int64(3481): 'Comedy|Drama|Romance',
#  np.int64(3897): 'Drama',
#  np.int64(1): 'Adventure|Animation|Children|Comedy|Fantasy',
#  np.int64(1246): 'Drama',
#  np.int64(32587): 'Action|Crime|Film-Noir|Mystery|Thriller',
#  np.int64(33660): 'Drama|Romance',
#  np.int64(34162): 'Comedy|Romance',
#  np.int64(36529): 'Action|Crime|Drama|Thriller|War',
#  np.int64(2146): 'Drama|Romance',
#  np.int64(37384): 'Comedy',
#  np.int64(40955): 'Comedy|Drama',
#  np.int64(44889): 'Comedy|Drama|Musical',
#  np.int64(61323): 'Comedy|Crime|Drama',
#  np.int64(39): 'Comedy|Romance',
#  np.int64(1059): 'Drama|Romance',
#  np.int64(2762): 'Drama|Horror|Mystery',
#  np.int64(4370): 'Adventure|Drama|Sci-Fi',
#  np.int64(5464): 'Crime|Drama',
#  np.int64(7078): 'Drama',
#  np.int64(7444): 'Comedy|Fantasy|Romance',
#  np.int64(7451): 'Comedy',
#  np.int64(48516): 'Crime|Drama|Thriller',
#  np.int64(54997): 'Action|Crime|Drama|Western',
#  np.int64(55290): 'Crime|Drama|Mystery',
#  np.int64(91500): 'Action|Adventure|Drama|Sci-Fi|Thriller',
#  np.int64(91529): 'Action|Adventure|Crime|IMAX',
#  np.int64(98961): 'Action|Drama|Thriller',
#  np.int64(47): 'Mystery|Thriller',
#  np.int64(50): 'Crime|Mystery|Thriller',
#  np.int64(175): 'Drama',
#  np.int64(288): 'Action|Crime|Thriller',
#  np.int64(628): 'Crime|Drama|Mystery|Thriller',
#  np.int64(1193): 'Drama',
#  np.int64(1219): 'Crime|Horror',
#  np.int64(1258): 'Horror',
#  np.int64(1343): 'Thriller',
#  np.int64(1625): 'Drama|Mystery|Thriller',
#  np.int64(1704): 'Drama|Romance',
#  np.int64(2160): 'Drama|Horror|Thriller',
#  np.int64(2329): 'Crime|Drama',
#  np.int64(2700): 'Animation|Comedy|Musical',
#  np.int64(2959): 'Action|Crime|Drama|Thriller',
#  np.int64(3176): 'Drama|Mystery|Thriller',
#  np.int64(3948): 'Comedy',
#  np.int64(6188): 'Comedy',
#  np.int64(6290): 'Horror',
#  np.int64(8950): 'Drama|Mystery|Thriller',
#  np.int64(34323): 'Action|Crime|Horror',
#  np.int64(40278): 'Action|Drama|War',
#  np.int64(66097): 'Animation|Fantasy|Thriller',
#  np.int64(68157): 'Action|Drama|War',
#  np.int64(74458): 'Drama|Mystery|Thriller',
#  np.int64(104879): 'Drama|Mystery|Thriller',
#  np.int64(106100): 'Drama',
#  np.int64(112515): 'Drama|Horror|Thriller',
#  np.int64(58559): 'Action|Crime|Drama|IMAX',
#  np.int64(5952): 'Adventure|Fantasy',
#  np.int64(152711): 'Documentary',
#  np.int64(16): 'Crime|Drama',
#  np.int64(17): 'Drama|Romance',
#  np.int64(21): 'Comedy|Crime|Thriller',
#  np.int64(28): 'Drama|Romance',
#  np.int64(32): 'Mystery|Sci-Fi|Thriller',
#  np.int64(34): 'Children|Drama',
#  np.int64(36): 'Crime|Drama',
#  np.int64(45): 'Comedy|Drama|Thriller',
#  np.int64(52): 'Comedy|Drama|Romance',
#  np.int64(111): 'Crime|Drama|Thriller',
#  np.int64(150): 'Adventure|Drama|IMAX',
#  np.int64(199): 'Drama|Musical|Romance',
#  np.int64(222): 'Drama|Romance',
#  np.int64(232): 'Comedy|Drama|Romance',
#  np.int64(235): 'Comedy|Drama',
#  np.int64(246): 'Documentary',
#  np.int64(247): 'Crime|Drama',
#  np.int64(249): 'Drama|Romance',
#  np.int64(261): 'Drama',
#  np.int64(262): 'Children|Drama',
#  np.int64(300): 'Drama',
#  np.int64(307): 'Drama',
#  np.int64(308): 'Comedy|Drama',
#  np.int64(318): 'Crime|Drama',
#  np.int64(329): 'Adventure|Drama|Sci-Fi',
#  np.int64(337): 'Drama',
#  np.int64(377): 'Action|Romance|Thriller',
#  np.int64(380): 'Action|Adventure|Comedy|Romance|Thriller',
#  np.int64(412): 'Drama',
#  np.int64(440): 'Comedy|Romance',
#  np.int64(454): 'Drama|Thriller',
#  np.int64(457): 'Thriller',
#  np.int64(475): 'Drama',
#  np.int64(480): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(497): 'Comedy|Romance',
#  np.int64(515): 'Drama|Romance',
#  np.int64(527): 'Drama|War',
#  np.int64(529): 'Drama',
#  np.int64(534): 'Drama|Romance',
#  np.int64(535): 'Drama',
#  np.int64(539): 'Comedy|Drama|Romance',
#  np.int64(543): 'Comedy|Romance|Thriller',
#  np.int64(562): 'Comedy|Drama',
#  np.int64(588): 'Adventure|Animation|Children|Comedy|Musical',
#  np.int64(589): 'Action|Sci-Fi',
#  np.int64(592): 'Action|Crime|Thriller',
#  np.int64(593): 'Crime|Horror|Thriller',
#  np.int64(595): 'Animation|Children|Fantasy|Musical|Romance|IMAX',
#  np.int64(597): 'Comedy|Romance',
#  np.int64(608): 'Comedy|Crime|Drama|Thriller',
#  np.int64(670): 'Drama',
#  np.int64(708): 'Comedy|Romance',
#  np.int64(720): 'Adventure|Animation|Comedy',
#  np.int64(733): 'Action|Adventure|Thriller',
#  np.int64(745): 'Animation|Children|Comedy',
#  np.int64(750): 'Comedy|War',
#  np.int64(780): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(858): 'Crime|Drama',
#  np.int64(898): 'Comedy|Drama|Romance',
#  np.int64(899): 'Comedy|Musical|Romance',
#  np.int64(903): 'Drama|Mystery|Romance|Thriller',
#  np.int64(904): 'Mystery|Thriller',
#  np.int64(905): 'Comedy|Romance',
#  np.int64(906): 'Drama|Thriller',
#  np.int64(909): 'Comedy|Drama|Romance',
#  np.int64(910): 'Comedy|Crime',
#  np.int64(912): 'Drama|Romance',
#  np.int64(913): 'Film-Noir|Mystery',
#  np.int64(914): 'Comedy|Drama|Musical|Romance',
#  np.int64(915): 'Comedy|Romance',
#  np.int64(916): 'Comedy|Drama|Romance',
#  np.int64(919): 'Adventure|Children|Fantasy|Musical',
#  np.int64(922): 'Drama|Film-Noir|Romance',
#  np.int64(923): 'Drama|Mystery',
#  np.int64(924): 'Adventure|Drama|Sci-Fi',
#  np.int64(926): 'Drama',
#  np.int64(927): 'Comedy',
#  np.int64(928): 'Drama|Mystery|Romance|Thriller',
#  np.int64(930): 'Film-Noir|Romance|Thriller',
#  np.int64(936): 'Comedy|Romance',
#  np.int64(944): 'Drama',
#  np.int64(945): 'Comedy|Musical|Romance',
#  np.int64(948): 'Drama|Romance|Western',
#  np.int64(950): 'Comedy|Crime',
#  np.int64(951): 'Comedy|Romance',
#  np.int64(954): 'Drama',
#  np.int64(955): 'Comedy|Romance',
#  np.int64(956): 'Drama|Romance',
#  np.int64(965): 'Drama|Mystery|Thriller',
#  np.int64(968): 'Horror|Sci-Fi|Thriller',
#  np.int64(969): 'Adventure|Comedy|Romance|War',
#  np.int64(986): 'Adventure|Children',
#  np.int64(1022): 'Animation|Children|Fantasy|Musical|Romance',
#  np.int64(1033): 'Animation|Children|Drama',
#  np.int64(1035): 'Musical|Romance',
#  np.int64(1041): 'Drama',
#  np.int64(1042): 'Comedy|Drama',
#  np.int64(1066): 'Comedy|Musical|Romance',
#  np.int64(1079): 'Comedy|Crime',
#  np.int64(1089): 'Crime|Mystery|Thriller',
#  np.int64(1097): 'Children|Drama|Sci-Fi',
#  np.int64(1103): 'Drama',
#  np.int64(1104): 'Drama',
#  np.int64(1124): 'Drama',
#  np.int64(1136): 'Adventure|Comedy|Fantasy',
#  np.int64(1148): 'Animation|Children|Comedy|Crime',
#  np.int64(1171): 'Comedy',
#  np.int64(1177): 'Drama|Romance',
#  np.int64(1185): 'Drama',
#  np.int64(1187): 'Drama',
#  np.int64(1188): 'Comedy|Romance',
#  np.int64(1189): 'Documentary',
#  np.int64(1196): 'Action|Adventure|Sci-Fi',
#  np.int64(1197): 'Action|Adventure|Comedy|Fantasy|Romance',
#  np.int64(1198): 'Action|Adventure',
#  np.int64(1203): 'Drama',
#  np.int64(1204): 'Adventure|Drama|War',
#  np.int64(1207): 'Drama',
#  np.int64(1210): 'Action|Adventure|Sci-Fi',
#  np.int64(1212): 'Film-Noir|Mystery|Thriller',
#  np.int64(1214): 'Horror|Sci-Fi',
#  np.int64(1217): 'Drama|War',
#  np.int64(1222): 'Drama|War',
#  np.int64(1223): 'Adventure|Animation|Children|Comedy|Sci-Fi',
#  np.int64(1224): 'Action|Drama|Romance|War',
#  np.int64(1225): 'Drama',
#  np.int64(1230): 'Comedy|Romance',
#  np.int64(1231): 'Drama',
#  np.int64(1234): 'Comedy|Crime',
#  np.int64(1235): 'Comedy|Drama|Romance',
#  np.int64(1240): 'Action|Sci-Fi|Thriller',
#  np.int64(1242): 'Drama|War',
#  np.int64(1243): 'Comedy|Drama',
#  np.int64(1247): 'Comedy|Drama|Romance',
#  np.int64(1250): 'Adventure|Drama|War',
#  np.int64(1252): 'Crime|Film-Noir|Mystery|Thriller',
#  np.int64(1253): 'Drama|Sci-Fi|Thriller',
#  np.int64(1254): 'Action|Adventure|Drama|Western',
#  np.int64(1259): 'Adventure|Drama',
#  np.int64(1260): 'Crime|Film-Noir|Thriller',
#  np.int64(1262): 'Action|Adventure|Drama|War',
#  np.int64(1266): 'Drama|Western',
#  np.int64(1267): 'Crime|Thriller|War',
#  np.int64(1270): 'Adventure|Comedy|Sci-Fi',
#  np.int64(1272): 'Drama|War',
#  np.int64(1278): 'Comedy|Fantasy',
#  np.int64(1281): 'Comedy|Drama|War',
#  np.int64(1285): 'Comedy',
#  np.int64(1291): 'Action|Adventure',
#  np.int64(1292): 'Comedy|Drama',
#  np.int64(1293): 'Drama',
#  np.int64(1296): 'Drama|Romance',
#  np.int64(1303): 'Adventure|Drama',
#  np.int64(1307): 'Comedy|Romance',
#  np.int64(1333): 'Horror|Thriller',
#  np.int64(1344): 'Crime|Drama|Thriller',
#  np.int64(1350): 'Horror|Mystery|Thriller',
#  np.int64(1353): 'Comedy|Drama|Romance',
#  np.int64(1354): 'Drama|Mystery',
#  np.int64(1356): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(1358): 'Drama',
#  np.int64(1366): 'Drama',
#  np.int64(1372): 'Action|Mystery|Sci-Fi',
#  np.int64(1374): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(1376): 'Adventure|Comedy|Sci-Fi',
#  np.int64(1380): 'Comedy|Musical|Romance',
#  np.int64(1387): 'Action|Horror',
#  np.int64(1393): 'Drama|Romance',
#  np.int64(1394): 'Comedy',
#  np.int64(1396): 'Action|Comedy|Crime|Drama|Sci-Fi',
#  np.int64(1407): 'Comedy|Horror|Mystery|Thriller',
#  np.int64(1408): 'Action|Romance|War|Western',
#  np.int64(1411): 'Crime|Drama|Romance',
#  np.int64(1413): 'Drama',
#  np.int64(1423): 'Drama',
#  np.int64(1449): 'Comedy',
#  np.int64(1466): 'Crime|Drama',
#  np.int64(1496): 'Drama|Romance',
#  np.int64(1500): 'Comedy|Crime|Romance',
#  np.int64(1537): 'Comedy|Drama|Romance',
#  np.int64(1545): 'Drama',
#  np.int64(1569): 'Comedy|Romance',
#  np.int64(1573): 'Action|Crime|Drama|Thriller',
#  np.int64(1580): 'Action|Comedy|Sci-Fi',
#  np.int64(1610): 'Action|Adventure|Thriller',
#  np.int64(1617): 'Crime|Film-Noir|Mystery|Thriller',
#  np.int64(1635): 'Drama',
#  np.int64(1650): 'Drama',
#  np.int64(1653): 'Drama|Sci-Fi|Thriller',
#  np.int64(1674): 'Drama|Romance|Thriller',
#  np.int64(1680): 'Drama|Romance',
#  np.int64(1682): 'Comedy|Drama|Sci-Fi',
#  np.int64(1683): 'Drama|Romance',
#  np.int64(1717): 'Comedy|Horror|Mystery|Thriller',
#  np.int64(1719): 'Drama',
#  np.int64(1721): 'Drama|Romance',
#  np.int64(1748): 'Adventure|Film-Noir|Sci-Fi|Thriller',
#  np.int64(1777): 'Comedy|Romance',
#  np.int64(1797): 'Documentary|IMAX',
#  np.int64(1834): 'Crime|Drama|Mystery|Thriller',
#  np.int64(1893): 'Drama',
#  np.int64(1902): 'Drama|Romance',
#  np.int64(1909): 'Action|Crime|Mystery|Sci-Fi|Thriller',
#  np.int64(1912): 'Comedy|Crime|Drama|Romance|Thriller',
#  np.int64(1913): 'Drama|Mystery',
#  np.int64(1921): 'Drama|Sci-Fi|Thriller',
#  np.int64(1931): 'Adventure|Drama',
#  np.int64(1938): 'Drama',
#  np.int64(1940): 'Drama',
#  np.int64(1945): 'Crime|Drama',
#  np.int64(1947): 'Drama|Musical|Romance',
#  np.int64(1951): 'Drama|Musical',
#  np.int64(1952): 'Drama',
#  np.int64(1953): 'Action|Crime|Thriller',
#  np.int64(1954): 'Drama',
#  np.int64(1955): 'Drama',
#  np.int64(1957): 'Drama',
#  np.int64(1959): 'Drama|Romance',
#  np.int64(1960): 'Drama',
#  np.int64(1961): 'Drama',
#  np.int64(1962): 'Drama',
#  np.int64(1994): 'Horror|Thriller',
#  np.int64(1997): 'Horror|Mystery',
#  np.int64(2006): 'Action|Comedy|Romance',
#  np.int64(2019): 'Action|Adventure|Drama',
#  np.int64(2020): 'Drama|Romance',
#  np.int64(2022): 'Drama',
#  np.int64(2054): 'Adventure|Children|Comedy|Fantasy|Sci-Fi',
#  np.int64(2058): 'Action|Crime|Drama|Mystery|Thriller',
#  np.int64(2064): 'Documentary',
#  np.int64(2066): 'Film-Noir',
#  np.int64(2070): 'Drama|Romance|Western',
#  np.int64(2076): 'Drama|Mystery|Thriller',
#  np.int64(2078): 'Animation|Children|Comedy|Musical',
#  np.int64(2080): 'Animation|Children|Comedy|Romance',
#  np.int64(2085): 'Adventure|Animation|Children',
#  np.int64(2100): 'Comedy|Fantasy|Romance',
#  np.int64(2108): 'Comedy|Romance',
#  np.int64(2114): 'Drama',
#  np.int64(2118): 'Thriller',
#  np.int64(2139): 'Adventure|Animation|Children|Drama',
#  np.int64(2145): 'Comedy|Drama|Romance',
#  np.int64(2171): 'Comedy|Drama|Romance',
#  np.int64(2186): 'Crime|Drama|Film-Noir|Thriller',
#  np.int64(2194): 'Action|Crime|Drama',
#  np.int64(2202): 'Drama|War',
#  np.int64(2203): 'Crime|Drama|Thriller',
#  np.int64(2206): 'Film-Noir|Mystery|Thriller',
#  np.int64(2208): 'Drama|Mystery|Thriller',
#  np.int64(2243): 'Comedy|Drama|Romance',
#  np.int64(2248): 'Comedy|Drama|Romance',
#  np.int64(2268): 'Crime|Drama|Thriller',
#  np.int64(2291): 'Drama|Fantasy|Romance',
#  np.int64(2295): 'Comedy',
#  np.int64(2300): 'Comedy',
#  np.int64(2310): 'Drama',
#  np.int64(2313): 'Drama',
#  np.int64(2324): 'Comedy|Drama|Romance|War',
#  np.int64(2334): 'Action|Thriller',
#  np.int64(2336): 'Drama',
#  np.int64(2355): 'Adventure|Animation|Children|Comedy',
#  np.int64(2357): 'Drama',
#  np.int64(2391): 'Crime|Drama|Thriller',
#  np.int64(2394): 'Animation|Musical',
#  np.int64(2396): 'Comedy|Drama|Romance',
#  np.int64(2420): 'Drama',
#  np.int64(2424): 'Comedy|Romance',
#  np.int64(2442): 'Drama',
#  np.int64(2494): 'Documentary',
#  np.int64(2502): 'Comedy|Crime',
#  np.int64(2529): 'Action|Drama|Sci-Fi',
#  np.int64(2550): 'Horror|Thriller',
#  np.int64(2565): 'Drama|Musical|Romance',
#  np.int64(2571): 'Action|Sci-Fi|Thriller',
#  np.int64(2581): 'Comedy|Romance',
#  np.int64(2583): 'Comedy|Drama',
#  np.int64(2600): 'Action|Sci-Fi|Thriller',
#  np.int64(2612): 'Drama|Film-Noir',
#  np.int64(2628): 'Action|Adventure|Sci-Fi',
#  np.int64(2640): 'Action|Adventure|Sci-Fi',
#  np.int64(2641): 'Action|Sci-Fi',
#  np.int64(2664): 'Horror|Sci-Fi|Thriller',
#  np.int64(2692): 'Action|Crime',
#  np.int64(2693): 'Documentary',
#  np.int64(2710): 'Drama|Horror|Thriller',
#  np.int64(2712): 'Drama|Mystery|Thriller',
#  np.int64(2716): 'Action|Comedy|Sci-Fi',
#  np.int64(2723): 'Action|Comedy|Fantasy',
#  np.int64(2726): 'Crime|Film-Noir',
#  np.int64(2728): 'Action|Drama|Romance|War',
#  np.int64(2745): 'Drama',
#  np.int64(2761): 'Adventure|Animation|Children|Drama|Sci-Fi',
#  np.int64(2791): 'Comedy',
#  np.int64(2797): 'Comedy|Drama|Fantasy|Romance',
#  np.int64(2801): 'Drama|Romance',
#  np.int64(2804): 'Children|Comedy',
#  np.int64(2863): 'Adventure|Comedy|Musical',
#  np.int64(2871): 'Adventure|Drama|Thriller',
#  np.int64(2872): 'Adventure|Fantasy',
#  np.int64(2918): 'Comedy',
#  np.int64(2919): 'Drama|Romance|War',
#  np.int64(2927): 'Drama|Romance',
#  np.int64(2935): 'Comedy|Romance',
#  np.int64(2937): 'Comedy',
#  np.int64(2940): 'Drama|Film-Noir|Mystery|Romance',
#  np.int64(2941): 'Musical|Romance|War',
#  np.int64(2952): 'Crime|Drama|Thriller',
#  np.int64(2966): 'Adventure|Drama',
#  np.int64(2967): 'Drama|Thriller',
#  np.int64(2968): 'Adventure|Comedy|Fantasy|Sci-Fi',
#  np.int64(2987): 'Adventure|Animation|Children|Comedy|Crime|Fantasy|Mystery',
#  np.int64(3000): 'Action|Adventure|Animation|Drama|Fantasy',
#  np.int64(3006): 'Drama|Thriller',
#  np.int64(3011): 'Drama',
#  np.int64(3030): 'Action|Adventure',
#  np.int64(3039): 'Comedy',
#  np.int64(3044): 'Mystery|Romance|Thriller',
#  np.int64(3072): 'Comedy|Romance',
#  np.int64(3095): 'Drama',
#  np.int64(3097): 'Comedy|Drama|Romance',
#  np.int64(3101): 'Drama|Thriller',
#  np.int64(3111): 'Drama',
#  np.int64(3114): 'Adventure|Animation|Children|Comedy|Fantasy',
#  np.int64(3115): 'Drama',
#  np.int64(3125): 'Drama',
#  np.int64(3135): 'Drama',
#  np.int64(3147): 'Crime|Drama',
#  np.int64(3152): 'Drama',
#  np.int64(3160): 'Drama',
#  np.int64(3174): 'Comedy|Drama',
#  np.int64(3175): 'Adventure|Comedy|Sci-Fi',
#  np.int64(3181): 'Drama',
#  np.int64(3211): 'Drama',
#  np.int64(3260): 'Drama',
#  np.int64(3273): 'Comedy|Horror|Mystery|Thriller',
#  np.int64(3306): 'Comedy',
#  np.int64(3307): 'Comedy|Drama|Romance',
#  np.int64(3310): 'Comedy|Drama',
#  np.int64(3317): 'Comedy|Drama',
#  np.int64(3330): 'Drama|Romance',
#  np.int64(3341): 'Comedy',
#  np.int64(3384): 'Action|Crime',
#  np.int64(3386): 'Drama|Mystery|Thriller',
#  np.int64(3408): 'Drama',
#  np.int64(3424): 'Drama',
#  np.int64(3435): 'Crime|Drama|Film-Noir',
#  np.int64(3447): 'Drama',
#  np.int64(3451): 'Drama',
#  np.int64(3461): 'Adventure|Drama|Thriller',
#  np.int64(3462): 'Comedy|Drama|Romance',
#  np.int64(3475): 'Drama|Romance',
#  np.int64(3489): 'Adventure|Comedy|Fantasy',
#  np.int64(3498): 'Drama',
#  np.int64(3504): 'Comedy|Drama',
#  np.int64(3512): 'Drama|Romance',
#  np.int64(3515): 'Comedy|Romance',
#  np.int64(3526): 'Comedy|Drama',
#  np.int64(3536): 'Comedy|Drama|Romance',
#  np.int64(3546): 'Drama|Horror|Thriller',
#  np.int64(3548): 'Comedy|Drama',
#  np.int64(3549): 'Comedy|Musical|Romance',
#  np.int64(3566): 'Comedy|Drama',
#  np.int64(3608): 'Adventure|Comedy',
#  np.int64(3629): 'Adventure|Comedy|Romance',
#  np.int64(3675): 'Comedy|Musical|Romance',
#  np.int64(3723): 'Drama',
#  np.int64(3730): 'Drama|Mystery',
#  np.int64(3735): 'Crime|Drama',
#  np.int64(3793): 'Action|Adventure|Sci-Fi',
#  np.int64(3801): 'Drama|Mystery',
#  np.int64(3811): 'Drama|War',
#  np.int64(3816): 'Drama',
#  np.int64(3849): 'Horror|Mystery|Thriller',
#  np.int64(3859): 'Documentary',
#  np.int64(3910): 'Drama|Musical',
#  np.int64(3911): 'Comedy',
#  np.int64(3932): 'Horror|Sci-Fi',
#  np.int64(3949): 'Drama',
#  np.int64(3967): 'Drama',
#  np.int64(3983): 'Drama|Romance',
#  np.int64(3994): 'Drama|Sci-Fi',
#  np.int64(3996): 'Action|Drama|Romance',
#  np.int64(4007): 'Drama',
#  np.int64(4019): 'Drama',
#  np.int64(4027): 'Adventure|Comedy|Crime',
#  np.int64(4029): 'Comedy|Drama',
#  np.int64(4046): 'Drama',
#  np.int64(4077): 'Drama|Thriller',
#  np.int64(4113): 'Drama',
#  np.int64(4160): 'Drama|Romance',
#  np.int64(4164): 'Drama',
#  np.int64(4171): 'Documentary',
#  np.int64(4184): 'Comedy|Drama|Romance',
#  np.int64(4190): 'Drama',
#  np.int64(4191): 'Comedy|Drama|Romance',
#  np.int64(4211): 'Drama',
#  np.int64(4232): 'Action|Adventure|Children|Comedy',
#  np.int64(4246): 'Comedy|Drama|Romance',
#  np.int64(4259): 'Drama|Romance',
#  np.int64(4263): 'Drama',
#  np.int64(4292): 'Drama',
#  np.int64(4306): 'Adventure|Animation|Children|Comedy|Fantasy|Romance',
#  np.int64(4333): 'Comedy|Crime',
#  np.int64(4347): 'Comedy|Drama',
#  np.int64(4359): 'Comedy',
#  np.int64(4361): 'Comedy|Romance',
#  np.int64(4380): 'Drama|Romance',
#  np.int64(4447): 'Comedy|Romance',
#  np.int64(4448): 'Action|Drama',
#  np.int64(4465): 'Drama',
#  np.int64(4495): 'Comedy|Romance',
#  np.int64(4537): 'Drama',
#  np.int64(4546): 'Drama|Thriller',
#  np.int64(4571): 'Adventure|Comedy|Sci-Fi',
#  np.int64(4641): 'Comedy|Drama',
#  np.int64(4678): 'Comedy',
#  np.int64(4787): 'Drama',
#  np.int64(4801): 'Drama',
#  np.int64(4809): 'Drama',
#  np.int64(4823): 'Comedy|Romance',
#  np.int64(4835): 'Drama',
#  np.int64(4857): 'Drama|Musical',
#  np.int64(4881): 'Crime|Drama',
#  np.int64(4902): 'Drama|Fantasy|Horror|Thriller|War',
#  np.int64(4920): 'Drama|Romance',
#  np.int64(4963): 'Crime|Thriller',
#  np.int64(4970): 'Drama',
#  np.int64(4973): 'Comedy|Romance',
#  np.int64(4979): 'Comedy|Drama',
#  np.int64(4980): 'Adventure|Comedy|Fantasy|Sci-Fi',
#  np.int64(4993): 'Adventure|Fantasy',
#  np.int64(5008): 'Drama|Mystery|Thriller',
#  np.int64(5012): 'Drama|Musical|Romance',
#  np.int64(5015): 'Drama|Romance',
#  np.int64(5034): 'Drama|Romance',
#  np.int64(5064): 'Action|Adventure|Drama|Thriller',
#  np.int64(5114): 'Drama',
#  np.int64(5135): 'Comedy|Romance',
#  np.int64(5224): 'Documentary',
#  np.int64(5266): 'Thriller',
#  np.int64(5291): 'Crime|Drama|Mystery',
#  np.int64(5294): 'Crime|Drama|Thriller',
#  np.int64(5349): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(5377): 'Comedy|Drama|Romance',
#  np.int64(5379): 'Drama',
#  np.int64(5398): 'Drama',
#  np.int64(5404): 'Drama|Romance',
#  np.int64(5445): 'Action|Crime|Mystery|Sci-Fi|Thriller',
#  np.int64(5446): 'Adventure|Drama',
#  np.int64(5450): 'Comedy|Drama|Romance',
#  np.int64(5470): 'Comedy|Romance',
#  np.int64(5483): 'Documentary',
#  np.int64(5502): 'Horror|Sci-Fi|Thriller',
#  np.int64(5505): 'Comedy|Drama',
#  np.int64(5527): 'Drama|Romance',
#  np.int64(5528): 'Drama|Thriller',
#  np.int64(5577): 'Comedy|Drama',
#  np.int64(5601): 'Children|Drama',
#  np.int64(5603): 'Comedy|Crime',
#  np.int64(5618): 'Adventure|Animation|Fantasy',
#  np.int64(5633): 'Drama',
#  np.int64(5644): 'Drama',
#  np.int64(5669): 'Documentary',
#  np.int64(5673): 'Comedy|Drama|Romance',
#  np.int64(5682): 'Drama',
#  np.int64(5685): 'Comedy|Drama',
#  np.int64(5690): 'Animation|Drama|War',
#  np.int64(5747): 'Drama|War',
#  np.int64(5791): 'Drama|Romance',
#  np.int64(5802): 'Comedy',
#  np.int64(5812): 'Drama|Romance',
#  np.int64(5816): 'Adventure|Fantasy',
#  np.int64(5820): 'Documentary|Musical',
#  np.int64(5876): 'Drama|Thriller|War',
#  np.int64(5878): 'Drama|Romance',
#  np.int64(5954): 'Crime|Drama',
#  np.int64(5971): 'Animation|Children|Drama|Fantasy',
#  np.int64(5989): 'Crime|Drama',
#  np.int64(5991): 'Comedy|Crime|Drama|Musical',
#  np.int64(5994): 'Drama|Romance',
#  np.int64(6016): 'Action|Adventure|Crime|Drama|Thriller',
#  np.int64(6031): 'Drama|Romance',
#  np.int64(6041): 'Drama',
#  np.int64(6101): 'Drama|Mystery|Thriller',
#  np.int64(6104): 'Comedy',
#  np.int64(6163): 'Romance|Thriller',
#  np.int64(6178): 'Drama|Romance',
#  np.int64(6181): 'Drama|War',
#  np.int64(6183): 'Comedy|Musical|Romance',
#  np.int64(6195): 'Documentary',
#  np.int64(6201): 'Drama|Romance',
#  np.int64(6218): 'Comedy|Drama|Romance',
#  np.int64(6228): 'Comedy|Romance|Thriller',
#  np.int64(6232): 'Adventure|Children|Drama',
#  np.int64(6254): 'Comedy|Romance',
#  np.int64(6269): 'Documentary',
#  np.int64(6286): 'Comedy|Crime|Drama',
#  np.int64(6291): 'Crime|Drama',
#  np.int64(6296): 'Comedy|Musical',
#  np.int64(6305): 'Drama|Sci-Fi',
#  np.int64(6331): 'Documentary',
#  np.int64(6333): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(6334): 'Drama',
#  np.int64(6350): 'Action|Adventure|Animation|Children|Fantasy|Sci-Fi',
#  np.int64(6367): 'Comedy|Romance',
#  np.int64(6377): 'Adventure|Animation|Children|Comedy',
#  np.int64(6380): 'Documentary',
#  np.int64(6385): 'Drama',
#  np.int64(6422): 'Drama|War|Western',
#  np.int64(6466): 'Drama|Romance',
#  np.int64(6515): 'Crime|Film-Noir',
#  np.int64(6545): 'Drama|Romance',
#  np.int64(6552): 'Crime|Drama|Thriller',
#  np.int64(6591): 'Drama',
#  np.int64(6592): 'Drama',
#  np.int64(6620): 'Comedy|Drama',
#  np.int64(6650): 'Comedy|Drama',
#  np.int64(6669): 'Drama',
#  np.int64(6768): 'Drama',
#  np.int64(6776): 'Comedy|Drama|Musical|Romance',
#  np.int64(6785): 'Comedy|Musical|Romance|Western',
#  np.int64(6787): 'Drama|Thriller',
#  np.int64(6791): 'Drama',
#  np.int64(6820): 'Drama|Horror|Thriller',
#  np.int64(6856): 'Drama|Musical',
#  np.int64(6867): 'Comedy|Drama',
#  np.int64(6874): 'Action|Crime|Thriller',
#  np.int64(6881): 'Comedy|Drama',
#  np.int64(6890): 'Drama',
#  np.int64(6909): 'Thriller',
#  np.int64(6918): 'Drama',
#  np.int64(6932): 'Crime|Drama',
#  np.int64(6936): 'Children|Comedy|Fantasy',
#  np.int64(6948): 'Documentary',
#  np.int64(6963): 'Documentary',
#  np.int64(6979): 'Drama|Sci-Fi|Thriller',
#  np.int64(6981): 'Drama',
#  np.int64(6984): 'Drama',
#  np.int64(6985): 'Drama',
#  np.int64(6993): 'Comedy|Drama|Romance',
#  np.int64(7013): 'Drama|Film-Noir|Thriller',
#  np.int64(7053): 'Comedy|Musical|Romance',
#  np.int64(7055): 'Comedy|Musical|Romance',
#  np.int64(7059): 'Children|Drama',
#  np.int64(7061): 'Drama|Romance',
#  np.int64(7062): 'Drama',
#  np.int64(7070): 'Action|Adventure|Western',
#  np.int64(7087): 'Adventure|Drama',
#  np.int64(7090): 'Action|Adventure|Drama',
#  np.int64(7121): 'Comedy|Romance',
#  np.int64(7139): 'Drama|Romance',
#  np.int64(7141): 'Documentary',
#  np.int64(7156): 'Documentary|War',
#  np.int64(7158): 'Drama',
#  np.int64(7160): 'Crime|Drama',
#  np.int64(7162): 'Drama|Romance|War',
#  np.int64(7212): 'Comedy|Romance',
#  np.int64(7217): 'Crime|Drama|Film-Noir|Romance|Thriller',
#  np.int64(7219): 'Drama',
#  np.int64(7234): 'Drama',
#  np.int64(7256): 'Adventure|Documentary',
#  np.int64(7285): 'Drama',
#  np.int64(7318): 'Drama',
#  np.int64(7323): 'Comedy|Drama',
#  np.int64(7361): 'Drama|Romance|Sci-Fi',
#  np.int64(7371): 'Drama|Mystery|Thriller',
#  np.int64(7382): 'Drama|Mystery|Thriller',
#  np.int64(7438): 'Action|Drama|Thriller',
#  np.int64(7440): 'Documentary',
#  np.int64(7479): 'Drama',
#  np.int64(7493): 'Drama',
#  np.int64(7572): 'Drama',
#  np.int64(7584): 'Comedy|Romance',
#  np.int64(7614): 'Musical|Romance|Western',
#  np.int64(7619): 'Drama',
#  np.int64(7649): 'Adventure|Sci-Fi',
#  np.int64(7700): 'Action|Adventure|Drama|Thriller',
#  np.int64(7705): 'Comedy|Romance',
#  np.int64(7713): 'Drama|Horror|Romance|Thriller',
#  np.int64(7714): 'Drama|Musical|Romance',
#  np.int64(7728): 'Crime|Drama|Film-Noir|Thriller',
#  np.int64(7766): 'Action|Drama|Thriller|War',
#  np.int64(7789): 'Drama',
#  np.int64(7834): 'Comedy|Crime|Mystery|Romance',
#  np.int64(7932): 'Documentary',
#  np.int64(7934): 'Comedy',
#  np.int64(7981): 'Crime|Drama|Thriller',
#  np.int64(7983): 'Comedy',
#  np.int64(8011): 'Documentary',
#  np.int64(8019): 'Drama|Horror|Mystery|Thriller',
#  np.int64(8167): 'Action|Adventure|Romance',
#  np.int64(8191): 'Drama',
#  np.int64(8207): 'Crime|Thriller',
#  np.int64(8228): 'Mystery',
#  np.int64(8235): 'Action|Comedy|Romance',
#  np.int64(8337): 'Drama|War',
#  np.int64(8338): 'Drama',
#  np.int64(8360): 'Adventure|Animation|Children|Comedy|Musical|Romance',
#  np.int64(8366): 'Comedy|Drama',
#  np.int64(8368): 'Adventure|Fantasy|IMAX',
#  np.int64(8376): 'Comedy',
#  np.int64(8424): 'Drama|Romance',
#  np.int64(8463): 'Drama',
#  np.int64(8464): 'Comedy|Documentary|Drama',
#  np.int64(8507): 'Crime|Drama|Horror',
#  np.int64(8530): 'Drama|Romance',
#  np.int64(8607): 'Adventure|Animation|Drama',
#  np.int64(8622): 'Documentary',
#  np.int64(8636): 'Action|Adventure|Sci-Fi|IMAX',
#  np.int64(8638): 'Drama|Romance',
#  np.int64(8645): 'Crime|Drama',
#  np.int64(8754): 'Drama',
#  np.int64(8784): 'Comedy|Drama|Romance',
#  np.int64(8809): 'Comedy|Romance',
#  np.int64(8827): 'Comedy|Documentary',
#  np.int64(8874): 'Comedy|Horror',
#  np.int64(8875): 'Drama',
#  np.int64(8880): 'Drama',
#  np.int64(8914): 'Drama|Sci-Fi',
#  np.int64(8938): 'Documentary',
#  np.int64(8949): 'Comedy|Drama|Romance',
#  np.int64(8951): 'Drama',
#  np.int64(8958): 'Drama',
#  np.int64(8961): 'Action|Adventure|Animation|Children|Comedy',
#  np.int64(8970): 'Drama',
#  np.int64(8979): 'Documentary',
#  np.int64(8983): 'Action|Drama|Romance',
#  np.int64(9018): 'Documentary|War',
#  np.int64(25753): 'Drama',
#  np.int64(25825): 'Drama|Film-Noir',
#  np.int64(25841): 'Drama',
#  np.int64(25865): 'Drama|Film-Noir',
#  np.int64(25886): 'Drama|Romance',
#  np.int64(25952): 'Comedy|Drama',
#  np.int64(26662): 'Adventure|Animation|Children|Drama|Fantasy',
#  np.int64(27731): 'Adventure|Animation|Children|Fantasy',
#  np.int64(27790): 'Children|Comedy|Crime|Drama|Fantasy',
#  np.int64(27820): 'Documentary|Drama',
#  np.int64(27834): 'Drama',
#  np.int64(27838): 'Drama|Thriller',
#  np.int64(27878): 'Documentary',
#  np.int64(27882): 'Documentary',
#  np.int64(30707): 'Drama',
#  np.int64(30749): 'Drama|War',
#  np.int64(30793): 'Adventure|Children|Comedy|Fantasy|IMAX',
#  np.int64(30812): 'Drama',
#  np.int64(30820): 'Drama',
#  np.int64(30822): 'Comedy|Drama',
#  np.int64(30850): 'Drama',
#  np.int64(31030): 'Children|Drama',
#  np.int64(31437): 'Drama',
#  np.int64(31658): 'Adventure|Animation|Fantasy|Romance',
#  np.int64(31903): 'Drama|Romance',
#  np.int64(32582): 'Documentary',
#  np.int64(32584): 'Drama',
#  np.int64(33166): 'Crime|Drama',
#  np.int64(33493): 'Action|Adventure|Sci-Fi',
#  np.int64(34359): 'Comedy',
#  np.int64(34405): 'Action|Adventure|Sci-Fi',
#  np.int64(34437): 'Comedy|Drama',
#  np.int64(34528): 'Comedy|Drama',
#  np.int64(34542): 'Documentary',
#  np.int64(36517): 'Drama|Thriller',
#  np.int64(37733): 'Action|Crime|Drama|Thriller',
#  np.int64(37741): 'Crime|Drama',
#  np.int64(38038): 'Adventure|Animation|Children|Comedy',
#  np.int64(38886): 'Comedy|Drama',
#  np.int64(39234): 'Drama',
#  np.int64(39292): 'Crime|Drama',
#  np.int64(40815): 'Adventure|Fantasy|Thriller|IMAX',
#  np.int64(40819): 'Drama|Musical|Romance',
#  np.int64(41566): 'Adventure|Children|Fantasy',
#  np.int64(41997): 'Action|Crime|Drama|Thriller',
#  np.int64(42002): 'Comedy|Musical',
#  np.int64(216): 'Comedy',
#  np.int64(541): 'Action|Sci-Fi|Thriller',
#  np.int64(908): 'Action|Adventure|Mystery|Romance|Thriller',
#  np.int64(1274): 'Action|Adventure|Animation|Sci-Fi',
#  np.int64(2694): 'Comedy',
#  np.int64(3527): 'Action|Sci-Fi|Thriller',
#  np.int64(4454): 'Animation|Drama|Sci-Fi|IMAX',
#  np.int64(4725): 'Horror|Thriller',
#  np.int64(8783): 'Drama|Mystery|Thriller',
#  np.int64(41569): 'Action|Adventure|Drama|Fantasy|Thriller',
#  np.int64(42422): 'Animation|Drama|Romance|Sci-Fi',
#  np.int64(47610): 'Drama|Fantasy|Mystery|Romance',
#  np.int64(52885): 'Animation|Mystery|Sci-Fi',
#  np.int64(53468): 'Comedy|Horror|Thriller',
#  np.int64(54503): 'Comedy',
#  np.int64(55167): 'Action|Adventure|Animation|Crime|Fantasy',
#  np.int64(56174): 'Action|Horror|Sci-Fi|Thriller|IMAX',
#  np.int64(56367): 'Comedy|Drama|Romance',
#  np.int64(57669): 'Comedy|Crime|Drama|Thriller',
#  np.int64(59141): 'Children|Comedy|Drama',
#  np.int64(60069): 'Adventure|Animation|Children|Romance|Sci-Fi',
#  np.int64(62336): 'Animation|Comedy|Fantasy|Sci-Fi',
#  np.int64(66934): 'Comedy|Drama|Musical|Sci-Fi',
#  np.int64(68237): 'Drama|Mystery|Sci-Fi|Thriller',
#  np.int64(68358): 'Action|Adventure|Sci-Fi|IMAX',
#  np.int64(68791): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(69757): 'Comedy|Drama|Romance',
#  np.int64(70286): 'Mystery|Sci-Fi|Thriller',
#  np.int64(72998): 'Action|Adventure|Sci-Fi|IMAX',
#  np.int64(79132): 'Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX',
#  np.int64(79702): 'Action|Comedy|Fantasy|Musical|Romance',
#  np.int64(82242): 'Action|Comedy',
#  np.int64(60516): 'Adventure|Children|Comedy|Romance|Sci-Fi',
#  np.int64(356): 'Comedy|Drama|Romance|War',
#  np.int64(55765): 'Crime|Drama|Thriller',
#  np.int64(58295): 'Action|Crime|Thriller',
#  np.int64(69122): 'Comedy|Crime',
#  np.int64(80906): 'Documentary',
#  np.int64(90439): 'Drama|Thriller',
#  np.int64(97304): 'Drama|Thriller',
#  np.int64(105504): 'Adventure|Drama|Thriller|IMAX',
#  np.int64(1916): 'Drama|Romance',
#  np.int64(2138): 'Adventure|Animation|Children|Drama|Fantasy',
#  np.int64(3266): 'Comedy|Crime|Drama|Thriller',
#  np.int64(3671): 'Comedy|Western',
#  np.int64(3676): 'Drama|Horror',
#  np.int64(4144): 'Drama|Romance',
#  np.int64(6818): 'Drama|War',
#  np.int64(7024): 'Drama',
#  np.int64(8477): 'Romance|Sci-Fi',
#  np.int64(25771): 'Fantasy',
#  np.int64(27773): 'Mystery|Thriller',
#  np.int64(30810): 'Adventure|Comedy|Fantasy',
#  np.int64(40491): 'Comedy|Drama',
#  np.int64(56782): 'Drama|Western',
#  np.int64(57502): 'Adventure|Animation|Drama|Horror',
#  np.int64(71899): 'Animation|Comedy|Drama',
#  np.int64(89745): 'Action|Adventure|Sci-Fi|IMAX',
#  np.int64(99764): 'Animation|Comedy|Drama|Fantasy|Sci-Fi',
#  np.int64(106766): 'Drama',
#  np.int64(108932): 'Action|Adventure|Animation|Children|Comedy|Fantasy',
#  np.int64(112421): 'Comedy|Drama|Mystery',
#  np.int64(122882): 'Action|Adventure|Sci-Fi|Thriller',
#  np.int64(134170): 'Action|Comedy|Fantasy|Sci-Fi',
#  np.int64(143367): 'Drama|Thriller',
#  np.int64(148881): 'Animation|Comedy',
#  np.int64(156605): '(no genres listed)',
#  np.int64(164179): 'Sci-Fi',
#  np.int64(168252): 'Action|Sci-Fi',
#  np.int64(176371): 'Sci-Fi',
#  np.int64(180031): 'Adventure|Drama|Fantasy',
#  np.int64(1801): 'Action|Adventure|Drama',
#  np.int64(5254): 'Action|Horror|Thriller',
#  np.int64(6373): 'Comedy|Drama|Fantasy|Romance',
#  np.int64(35836): 'Comedy|Romance',
#  np.int64(1732): 'Comedy|Crime',
#  np.int64(1357): 'Drama|Romance',
#  np.int64(6107): 'Drama|War',
#  np.int64(3265): 'Action|Crime|Drama|Thriller'}

# %%
# Étape 5 : Agrégation finale : genre ↔ tag ↔ count

# On "explose" les genres s'ils sont séparés par "|"
tagged_high_ratings['genres'] = tagged_high_ratings['genres'].str.split('|')
tagged_exploded = tagged_high_ratings.explode('genres')

tagged_exploded
# Out:
#       userId  movieId               tag   timestamp    genres
# 0          2    60756             funny  1445714994    Comedy
# 1          2    60756   Highly quotable  1445714996    Comedy
# 2          2    60756      will ferrell  1445714992    Comedy
# 3          2    89774      Boxing story  1445715207     Drama
# 4          2    89774               MMA  1445715200     Drama
# ...      ...      ...               ...         ...       ...
# 2376     610     3265  heroic bloodshed  1493843978     Drama
# 2376     610     3265  heroic bloodshed  1493843978  Thriller
# 2377     610   168248  Heroic Bloodshed  1493844270    Action
# 2377     610   168248  Heroic Bloodshed  1493844270     Crime
# 2377     610   168248  Heroic Bloodshed  1493844270  Thriller
#
# [6664 rows x 5 columns]

# %%
# Compter les combinaisons Genre / Tag
genre_tag_summary = (
    tagged_exploded
    .groupby(['genres', 'tag'])
    .size()
    .reset_index(name='count')
    .sort_values(by='count', ascending=False)
)

genre_tag_summary
# Out:
#         genres               tag  count
# 1971     Drama  In Netflix queue     20
# 2159     Drama       atmospheric     19
# 4321  Thriller      twist ending     16
# 3280   Mystery      twist ending     14
# 4304  Thriller          suspense     14
# ...        ...               ...    ...
# 18      Action              Borg      1
# 17      Action       Ben Stiller      1
# 4464   Western               oil      1
# 4463   Western             music      1
# 4462   Western          morality      1
#
# [4472 rows x 3 columns]

# %% [markdown]
# Ce tableau `genre_tag_summary` fournit une **analyse croisée entre les genres de films et les tags les plus utilisés** par les utilisateurs qui ont **attribué une note élevée** (`rating >= 4.0`). Voici quelques commentaires et interprétations intéressantes :
#
# ---
#
# ### **Ce que le tableau montre**
# - Chaque ligne représente une combinaison unique de **genre** et de **tag**.
# - La colonne `count` indique **le nombre de fois** qu’un certain **tag** a été associé à un film d’un certain **genre**, dans le contexte d’une **note élevée**.
# - Exemple :
#   - `Drama` + `In Netflix queue` a été tagué **20 fois** pour des films bien notés de genre `Drama`.
#   - `Thriller` + `twist ending` a été tagué **16 fois**, ce qui donne des indices sur ce que les gens aiment dans les thrillers.
#
# ---
#
# ### **Interprétations business**
# 1. **Découverte des préférences spectateurs par genre :**
#    - Les utilisateurs aiment les **films dramatiques** qu’ils prévoient de regarder plus tard (`In Netflix queue`) — ce tag peut refléter de l'intérêt ou de la recommandation indirecte.
#    - Les **Thrillers** avec des `twist endings` ou une ambiance `suspense` sont particulièrement appréciés → à prioriser pour la recommandation.
#
# 2. **Utilité pour un moteur de recommandation :**
#    - En analysant les tags les plus associés à des films bien notés dans chaque genre, on peut mieux orienter les recommandations personnalisées.
#    - Par exemple, recommander des **films “Mystery” avec des twists** à ceux qui aiment les “Thrillers” bien notés avec ce tag.
#
# 3. **Insights marketing / catégorisation :**
#    - Les plateformes peuvent créer des catégories comme :
#      - “**Mystery with a Twist**”
#      - “**Atmospheric Dramas**”
#      - “**Suspenseful Thrillers**”
#    - Ces regroupements peuvent améliorer l’engagement en renforçant la correspondance entre ce que les gens aiment et ce qu’on leur propose.
#
# ---
#
# ### À noter :
# - Ce tableau est basé **uniquement sur les films bien notés**, ce qui biaise volontairement l’analyse pour extraire **ce que les utilisateurs apprécient**.
# - Les tags sont **libres**, donc il peut y avoir du bruit (noms d’acteurs, fautes de frappe, etc.).
# - Une étape de **nettoyage/normalisation des tags** pourrait encore améliorer l’analyse.
#
# ---
#
# On peut aussi explorer les **tags associés aux films mal notés**. On pourrait comparer les deux profils de tags pour voir ce qui plaît ou non dans chaque genre.
